# %%
import quandl
import pandas as pd
import pickle
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')    

quandl.ApiConfig.api_key = "hGma1YxsN1KzgB4gjgsi"

def mortgage_30y():
    df = quandl.get("FMAC/MORTG", trim_start="1975-01-01", authtoken = quandl.ApiConfig.api_key)
    df["Value"] = (df["Value"]-df["Value"][0]) / df["Value"][0] * 100.0
    print(df.head())
    return df

mortgage_30y()
# Out:
#                Value
# Date
# 1975-01-01  0.000000
# 1975-02-01 -3.393425
# 1975-03-01 -5.620361
# 1975-04-01 -6.468717
# 1975-05-01 -5.514316
#                 Value
# Date
# 1975-01-01   0.000000
# 1975-02-01  -3.393425
# 1975-03-01  -5.620361
# 1975-04-01  -6.468717
# 1975-05-01  -5.514316
# 1975-06-01  -5.726405
# 1975-07-01  -5.726405
# 1975-08-01  -5.196182
# 1975-09-01  -3.181336
# 1975-10-01  -2.226935
# 1975-11-01  -2.969247
# 1975-12-01  -3.499470
# 1976-01-01  -4.347826
# 1976-02-01  -6.574761
# 1976-03-01  -7.104984
# 1976-04-01  -7.423118
# 1976-05-01  -6.998940
# 1976-06-01  -6.150583
# 1976-07-01  -5.302227
# 1976-08-01  -4.559915
# 1976-09-01  -4.772004
# 1976-10-01  -5.302227
# 1976-11-01  -6.574761
# 1976-12-01  -6.786850
# 1977-01-01  -7.529162
# 1977-02-01  -8.059385
# 1977-03-01  -7.847296
# 1977-04-01  -7.211029
# 1977-05-01  -6.468717
# 1977-06-01  -6.044539
# ...               ...
# 2014-04-01 -53.976670
# 2014-05-01 -55.567338
# 2014-06-01 -55.885472
# ...

# %%
quandl.ApiConfig.api_key = "hGma1YxsN1KzgB4gjgsi"

def state_list():
    fiddy_states = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states')
    return fiddy_states[0][0][1:]
    

def grab_initial_state_data():
    states = state_list()

    main_df = pd.DataFrame()

    for abbv in states:
        query = "FMAC/HPI_"+str(abbv)
        df = quandl.get(query, authtoken = quandl.ApiConfig.api_key )
        print(query)
        df[abbv] = (df[abbv]-df[abbv][0]) / df[abbv][0] * 100.0
        print(df.head())
        if main_df.empty:
            main_df = df
        else:
            main_df = main_df.join(df)
            
    pickle_out = open('fiddy_states.pickle','wb')
    pickle.dump(main_df, pickle_out)
    pickle_out.close()

def HPI_Benchmark():
    df = quandl.get("FMAC/HPI_USA", quandl.ApiConfig.api_key)
    df["United States"] = (df["United States"]-df["United States"][0]) / df["United States"][0] * 100.0
    return df

def mortgage_30y():
    df = quandl.get("FMAC/MORTG", trim_start="1975-01-01", authtoken = quandl.ApiConfig.api_key)
    df["Value"] = (df["Value"]-df["Value"][0]) / df["Value"][0] * 100.0
    df=df.resample('1D')
    df=df.resample('M')
    print(df.head())
    return df

mortgage_30y()
# Out:
#                Value
# Date
# 1975-01-31  0.000000
# 1975-02-28 -3.393425
# 1975-03-31 -5.620361
# 1975-04-30 -6.468717
# 1975-05-31 -5.514316
# C:\Users\Farhana_Fayez\Anaconda2\envs\wolt\lib\site-packages\ipykernel\__main__.py:37: FutureWarning:
# .resample() is now a deferred operation
# You called resample(...) on this deferred object which materialized it into a dataframe
# by implicitly taking the mean.  Use .resample(...).mean() instead
# C:\Users\Farhana_Fayez\Anaconda2\envs\wolt\lib\site-packages\ipykernel\__main__.py:38: FutureWarning:
# .resample() is now a deferred operation
# You called head(...) on this deferred object which materialized it into a dataframe
# by implicitly taking the mean.  Use .resample(...).mean() instead
# DatetimeIndexResampler [freq=<MonthEnd>, axis=0, closed=right, label=right, convention=start, base=0]

# %%
def mortgage_30y():
    df = quandl.get("FMAC/MORTG", trim_start="1975-01-01", authtoken = quandl.ApiConfig.api_key)
    df["Value"] = (df["Value"]-df["Value"][0]) / df["Value"][0] * 100.0
    df=df.resample('1D')
    df=df.resample('M')
    df.columns = ['M30']
    print(df.head())
    return df

mortgage_30y()
# Out:
# C:\Users\Farhana_Fayez\Anaconda2\envs\wolt\lib\site-packages\ipykernel\__main__.py:5: FutureWarning:
# .resample() is now a deferred operation
# You called resample(...) on this deferred object which materialized it into a dataframe
# by implicitly taking the mean.  Use .resample(...).mean() instead
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-80cff0b7418f> in <module>()
#       8     return df
#       9
# ---> 10 mortgage_30y()
#
# <ipython-input-27-80cff0b7418f> in mortgage_30y()
#       4     df=df.resample('1D')
#       5     df=df.resample('M')
# ----> 6     df.columns = ['M30']
#       7     print(df.head())
#       8     return df
#
# C:\Users\Farhana_Fayez\Anaconda2\envs\wolt\lib\site-packages\pandas\tseries\resample.pyc in __setattr__(self, attr, value)
#     192         if attr not in self._deprecated_valids:
# ...

# %%
HPI_data = pd.read_pickle('fiddy_states.pickle')
m30 = mortgage_30y()
#HPI_Bench = HPI_Benchmark()
m30.columns=['M30']
HPI = HPI_Benchmark.join(m30)
print(HPI.head())
# Out:
# C:\Users\Farhana_Fayez\Anaconda2\envs\wolt\lib\site-packages\ipykernel\__main__.py:5: FutureWarning:
# .resample() is now a deferred operation
# You called resample(...) on this deferred object which materialized it into a dataframe
# by implicitly taking the mean.  Use .resample(...).mean() instead
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-6597f48a2cb5> in <module>()
#       1 HPI_data = pd.read_pickle('fiddy_states.pickle')
# ----> 2 m30 = mortgage_30y()
#       3 #HPI_Bench = HPI_Benchmark()
#       4 m30.columns=['M30']
#       5 HPI = HPI_Benchmark.join(m30)
#
# <ipython-input-27-80cff0b7418f> in mortgage_30y()
#       4     df=df.resample('1D')
#       5     df=df.resample('M')
# ----> 6     df.columns = ['M30']
#       7     print(df.head())
#       8     return df
#
# ...
